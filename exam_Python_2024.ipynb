# %% [markdown]
# <a href="https://colab.research.google.com/github/RaesCeline/test/blob/main/exam_Python_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings;
warnings.filterwarnings('ignore');

import pandas as pd

# %% [markdown]
# For this exam you are asked to complete the Python code between the
#
# ```
# #start code here
#
# #end code here
# ```
#
# comments.
#
# You are allowed to use all the information available on the internet.

# %% [markdown]
# Please write your name and student number in the text box below:

# %%
# Name: Celine Raes

# Student number: 02003081

# %% [markdown]
# ## Total:    &nbsp; &nbsp; &nbsp;   / 20

# %% [markdown]
# **question 1 (2pts)**
#
# Create a Pandas DataFrame called `proteins` that looks like this:
#
# |   | Protein_A | Protein_B | Protein_C | Protein_D |
# |---|----------|----------|----------|----------|
# | Patient_1 | 0.1        | 0.5        | 0.1        | 0.9    |
# | Patient_2 | 0.4      | 0.7        | 0.4        | 0.4     |
# | Patient_3 | 0.2        | 0.6        | 0.2        |  0.6   |

# %%
#start code here

proteins = pd.DataFrame({'Protein_A': [0.1, 0.4, 0.2], 'Protein_B': [0.5,0.7,0.6], 'Protein_C': [0.1,0.4,0.2],'Protein_D':[0.9,0.4,0.6]}, index=['Patient_1', 'Patient_2','Patient_3'])

#end code here

proteins
# Out:
#            Protein_A  Protein_B  Protein_C  Protein_D
# Patient_1        0.1        0.5        0.1        0.9
# Patient_2        0.4        0.7        0.4        0.4
# Patient_3        0.2        0.6        0.2        0.6

# %% [markdown]
# The following Python code creates a Pandas DataFrame `df` that contains 100 datapoints (`P1--P100`) with each 10 attributes (`F0--F9`) and a binary class label `label`.

# %%
from sklearn.datasets import make_classification

num_features = 10

X, y = make_classification(n_features=num_features,random_state=42)

df = pd.DataFrame(X, columns=[f"F{i}" for i in range(num_features)])
df["label"] = y
df.index = [f"P{i+1}" for i in range(len(df))]
df
# Out:
#             F0        F1        F2        F3        F4        F5        F6  \
# P1   -1.140526  1.359706  0.861991  0.846092  0.606010 -1.556629  1.754794
# P2   -0.078734 -1.329332  0.627375 -1.193006 -0.773010  0.097676  0.497998
# P3    0.807427  0.730198 -1.285680  0.889484 -1.804882 -0.763259  0.048085
# P4    0.588465 -0.375121 -0.575002 -0.149518 -0.563725  0.412931  0.243687
# P5    1.636312 -1.640607 -1.360456 -0.941163 -1.430141  1.632411  0.130741
# ...        ...       ...       ...       ...       ...       ...       ...
# P96   0.531047  0.948005 -1.032233  0.996309 -1.008086 -2.038125 -0.351513
# P97  -0.963142  0.556003  0.964233  0.193754 -0.703176  1.149273  1.770801
# P98   0.950573 -2.255540 -0.270624 -1.692005  0.504047 -0.985726 -0.792873
# P99  -1.016951  0.554484  1.031102  0.175930  0.615936 -1.081063 -0.309546
# P100  1.897924 -1.614533 -1.693028 -0.838070  0.791663  1.158111  0.628346
#
#             F7        F8        F9  label
# P1    1.696456 -1.280429 -2.081929      1
# P2    0.959271  0.024510  1.451144      1
# P3   -0.904317 -1.627542  0.259723      0
# P4   -0.506943 -0.822220  0.244967      0
# P5   -1.435862 -0.440044  1.441273      0
# ...        ...       ...       ...    ...
# P96   1.676437 -1.870792  0.018418      0
# P97   1.812449 -0.034988 -0.626967      1
# P98  -1.035242 -0.530258 -0.107030      1
# P99  -1.251114  0.593101  0.326133      1
# P100 -0.897254  0.624120 -0.012247      0
#
# [100 rows x 11 columns]

# %% [markdown]
# **question 2 (1pt)**
#
# With DataFrame `df`, use **only** the Pandas DataFrame functions `head()` and `tail()` to print the datapoint with DataFrame index `P4`.

# %%
#start code here

first_rows = df.head()

last_rows = df.tail()

full_df = pd.concat([first_rows, last_rows])

datapoint_P4 = full_df.loc['P4']
print(datapoint_P4)

#end code here
# Out:
# F0    0.588465
# F1   -0.375121
# F2   -0.575002
# F3   -0.149518
# F4   -0.563725
# F5    0.412931
# F6    0.243687
# F7   -0.506943
# F8   -0.822220
# F9    0.244967
# Name: P4, dtype: float64

# %% [markdown]
# **question 3 (1pt)**
#
# With DataFrame `df`, print the same row using **only** index-based selection (`iloc`).

# %%
#start code here
df.iloc[3]
#end code here
# Out:
# F0       0.588465
# F1      -0.375121
# F2      -0.575002
# F3      -0.149518
# F4      -0.563725
# F5       0.412931
# F6       0.243687
# F7      -0.506943
# F8      -0.822220
# F9       0.244967
# label    0.000000
# Name: P4, dtype: float64

# %% [markdown]
# **question 4 (1pt)**
#
# With DataFrame `df`, use `.loc` to print the row with index `P99`.

# %%
#start code here
df.loc['P99']
#end code here
# Out:
# F0      -1.016951
# F1       0.554484
# F2       1.031102
# F3       0.175930
# F4       0.615936
# F5      -1.081063
# F6      -0.309546
# F7      -1.251114
# F8       0.593101
# F9       0.326133
# label    1.000000
# Name: P99, dtype: float64

# %% [markdown]
# **question 5 (2pts)**
#
# With DataFrame `df`, use `.loc` to print the columns `F0`, `F4`, `F8` and `label` for the rows with indices `P5` till `P50` (with `P50` included).

# %%
#start code here
df.loc['P5':'P50',['F0','F4','F8','label']]
#end code here
# Out:
#            F0        F4        F8  label
# P5   1.636312 -1.430141 -0.440044      0
# P6  -0.479370 -2.301921 -1.515191      1
# P7   2.489048 -0.059525 -3.241267      0
# P8  -0.239385 -0.426881 -1.012104      0
# P9   0.672873 -0.202193 -0.217681      0
# P10 -1.228234 -0.384556  1.006293      0
# P11 -0.827416 -1.129052 -0.524520      1
# P12  1.625375 -0.024125  0.198085      0
# P13  0.402384  1.355638  0.413435      0
# P14  0.307594 -0.385314  0.113517      0
# P15  1.449016  0.129221  0.109395      0
# P16 -0.320670 -0.907564 -0.576771      1
# P17 -0.568113  0.743264  0.170865      1
# P18  1.391755  0.216459  0.045572      0
# P19  0.254643  1.441569 -2.471645      0
# P20 -0.980944 -0.777817 -1.110576      1
# P21 -0.329294  0.311250  3.078881      1
# P22  1.696070  0.307300  0.812862      0
# P23  1.722513  0.401712  0.690144      0
# P24  1.170598  0.595157 -0.818221      0
# P25  0.409106 -0.411877 -0.487606      0
# P26  2.232454 -0.603985  0.086590      0
# P27  0.883469  0.081874  2.314659      0
# P28  0.159855  0.610586  0.559790      1
# P29 -1.310899  0.472597  0.256030      1
# P30 -1.096621 -1.124642 -1.534114      1
# P31 -2.654613  0.150302 -0.363612      1
# P32  1.203166 -0.125787  0.055725      0
# P33 -0.222100  1.143754  0.338496      0
# P34  1.393983 -0.978764 -0.444293      0
# P35  1.308576  0.471468  1.882024      0
# P36 -1.416933 -1.758739 -1.183259      1
# P37 -0.556581  0.538910 -1.037246      1
# P38  1.890331 -0.677162  0.975120      0
# P39 -0.218004  0.186454 -0.661786      0
# P40  1.347008  0.232050 -1.448084      0
# P41 -0.628041  1.876171  0.950424      1
# P42 -1.604993  0.074095  1.628616      1
# P43  1.778730  0.751387 -1.669405      0
# P44  1.650958  0.610370 -0.020902      0
# P45 -0.704270 -0.599393 -2.123896      1
# P46 -0.843897 -0.478749  1.255756      1
# P47  0.010666 -0.543425 -0.712846      0
# P48 -0.773361  0.248221 -0.459361      0
# P49 -1.457247  1.091507  1.246085      1
# P50 -1.809219 -0.096713 -0.544919      1

# %% [markdown]
# **question 6 (1pt)**
#
# From DataFrame `df`, create a Pandas Series called `result` that contains, for each row in `df`, value `True` if the value of `F0` is greater than and not equal to `F1`, value `False` otherwise. **Don't** use the Pandas functions `map()` or `apply()`.

# %%
#start code here

result = pd.Series(df['F0'] > df['F1'])

#end code here

result
# Out:
# P1      False
# P2       True
# P3       True
# P4       True
# P5       True
#         ...
# P96     False
# P97     False
# P98      True
# P99     False
# P100     True
# Length: 100, dtype: bool

# %% [markdown]
# **question 7 (1pt)**
#
# With DataFrame `df`, use `.iloc` to print the first, third and last rows.

# %%
#start code here
df.iloc[[0,2,99]]
#end code here
# Out:
#             F0        F1        F2        F3        F4        F5        F6  \
# P1   -1.140526  1.359706  0.861991  0.846092  0.606010 -1.556629  1.754794
# P3    0.807427  0.730198 -1.285680  0.889484 -1.804882 -0.763259  0.048085
# P100  1.897924 -1.614533 -1.693028 -0.838070  0.791663  1.158111  0.628346
#
#             F7        F8        F9  label
# P1    1.696456 -1.280429 -2.081929      1
# P3   -0.904317 -1.627542  0.259723      0
# P100 -0.897254  0.624120 -0.012247      0

# %% [markdown]
# **question 8 (2pts)**
#
# With DataFrame `df`, print **only** column `label` for all the rows for which the value in column `F3` is greater and not equal to 0, or for which the value in column `F7` is smaller or equal to 0.

# %%
#start code here

df.loc[(df['F3']>0)| (df['F7']<= 0)]

#end code here
# Out:
#             F0        F1        F2        F3        F4        F5        F6  \
# P1   -1.140526  1.359706  0.861991  0.846092  0.606010 -1.556629  1.754794
# P3    0.807427  0.730198 -1.285680  0.889484 -1.804882 -0.763259  0.048085
# P4    0.588465 -0.375121 -0.575002 -0.149518 -0.563725  0.412931  0.243687
# P5    1.636312 -1.640607 -1.360456 -0.941163 -1.430141  1.632411  0.130741
# P6   -0.479370 -1.083247  1.022556 -1.099391 -2.301921 -0.275052  1.366874
# ...        ...       ...       ...       ...       ...       ...       ...
# P96   0.531047  0.948005 -1.032233  0.996309 -1.008086 -2.038125 -0.351513
# P97  -0.963142  0.556003  0.964233  0.193754 -0.703176  1.149273  1.770801
# P98   0.950573 -2.255540 -0.270624 -1.692005  0.504047 -0.985726 -0.792873
# P99  -1.016951  0.554484  1.031102  0.175930  0.615936 -1.081063 -0.309546
# P100  1.897924 -1.614533 -1.693028 -0.838070  0.791663  1.158111  0.628346
#
#             F7        F8        F9
# P1    1.696456 -1.280429 -2.081929
# P3   -0.904317 -1.627542  0.259723
# P4   -0.506943 -0.822220  0.244967
# P5   -1.435862 -0.440044  1.441273
# P6   -0.249036 -1.515191  1.644968
# ...        ...       ...       ...
# P96   1.676437 -1.870792  0.018418
# P97   1.812449 -0.034988 -0.626967
# P98  -1.035242 -0.530258 -0.107030
# P99  -1.251114  0.593101  0.326133
# P100 -0.897254  0.624120 -0.012247
#
# [81 rows x 10 columns]

# %% [markdown]
# **question 9 (2pts)**
#
# From DataFrame `df`, create a Pandas Series called `result` that contains column `F1` minus the mean of column `F2`. Use the Pandas function `mean()`.

# %%
#start code here

result = pd.Series(df['F1'] - df['F2'].mean())

#end code here

result
# Out:
# P1      1.387420
# P2     -1.301618
# P3      0.757913
# P4     -0.347407
# P5     -1.612893
#           ...
# P96     0.975719
# P97     0.583717
# P98    -2.227826
# P99     0.582198
# P100   -1.586819
# Name: F1, Length: 100, dtype: float64

# %% [markdown]
# **question 10 (2pts)**
#
# From DataFrame `df`, create a Pandas Series called `result` that contains column `F1` minus the mean of column `F2`. Use the Pandas function `map()`.

# %%
#start code here

result = pd.Series(df['F1'].map(lambda x: x - df['F2'].mean()))

#end code here

result
# Out:
# P1      1.387420
# P2     -1.301618
# P3      0.757913
# P4     -0.347407
# P5     -1.612893
#           ...
# P96     0.975719
# P97     0.583717
# P98    -2.227826
# P99     0.582198
# P100   -1.586819
# Name: F1, Length: 100, dtype: float64

# %% [markdown]
# The following code splits the dataset `df` into a train and test set at random.
#
# The features for the train set are in `X_train` with the label in `y_train`.
# The features for the test set are in `X_test` with the label in `y_test`.

# %%
from sklearn.model_selection import train_test_split

X = df
y = X.pop("label")

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=42)

# %% [markdown]
# **question 11 (4pts)**
#
# We want to train a logistic regression model on the train set and evaluate the prediciton performance of the fitted model on the test set. Standardize the features, train the model and print the accuracy of the test set predictions. Use Scikit-learn.

# %%
#start code here

from sklearn.preprocessing import StandardScaler
scaler_std = StandardScaler()
scaler_std.fit(X_train)
X_train_std = pd.DataFrame(scaler_std.transform(X_train), columns=X_train.columns)
X_test_std = pd.DataFrame(scaler_std.transform(X_test),columns=X_test.columns)

from sklearn.linear_model import LogisticRegression
cls_std = LogisticRegression()
cls_std.fit(X_train_std,y_train)


print("Accuracy: {}".format(cls_std.score(X_test_std,y_test)))
#end code here
# Out:
# Accuracy: 0.86

# %% [markdown]
# **question 12 (1pt)**
#
# Print the test set class predictions of the model.

# %%
#start code here
predictions_std = cls_std.predict_proba(X_test_std)
predictions_std
#end code here
# Out:
# array([[5.85718282e-01, 4.14281718e-01],
#        [1.34816785e-01, 8.65183215e-01],
#        [6.63090807e-02, 9.33690919e-01],
#        [5.34090630e-02, 9.46590937e-01],
#        [4.52457227e-02, 9.54754277e-01],
#        [8.60747920e-01, 1.39252080e-01],
#        [9.40775856e-01, 5.92241438e-02],
#        [4.97626491e-01, 5.02373509e-01],
#        [3.61898928e-01, 6.38101072e-01],
#        [6.58692413e-01, 3.41307587e-01],
#        [9.68653433e-01, 3.13465666e-02],
#        [6.50739404e-03, 9.93492606e-01],
#        [4.75578640e-02, 9.52442136e-01],
#        [9.95649809e-01, 4.35019060e-03],
#        [4.72494330e-03, 9.95275057e-01],
#        [9.18395094e-01, 8.16049058e-02],
#        [6.74701950e-02, 9.32529805e-01],
#        [9.43534495e-01, 5.64655051e-02],
#        [9.71625527e-01, 2.83744727e-02],
#        [9.96893312e-01, 3.10668783e-03],
#        [7.94618279e-02, 9.20538172e-01],
#        [9.49912975e-01, 5.00870251e-02],
#        [3.68073620e-01, 6.31926380e-01],
#        [9.98895596e-01, 1.10440368e-03],
#        [4.55696136e-01, 5.44303864e-01],
#        [7.34425019e-02, 9.26557498e-01],
#        [1.14953347e-02, 9.88504665e-01],
#        [3.77371095e-01, 6.22628905e-01],
#        [3.95096831e-01, 6.04903169e-01],
#        [9.65356952e-03, 9.90346430e-01],
#        [9.93713917e-01, 6.28608276e-03],
#        [6.62459302e-01, 3.37540698e-01],
#        [8.08552525e-03, 9.91914475e-01],
#        [2.60268869e-01, 7.39731131e-01],
#        [1.73483950e-01, 8.26516050e-01],
#        [1.62400484e-01, 8.37599516e-01],
#        [9.96377146e-01, 3.62285405e-03],
#        [5.60996060e-01, 4.39003940e-01],
#        [4.29376367e-03, 9.95706236e-01],
#        [3.42786271e-01, 6.57213729e-01],
#        [1.37177623e-01, 8.62822377e-01],
#        [9.95818070e-01, 4.18192992e-03],
#        [8.55852896e-01, 1.44147104e-01],
#        [9.92853896e-01, 7.14610400e-03],
#        [7.70145161e-01, 2.29854839e-01],
#        [6.20661714e-01, 3.79338286e-01],
#        [8.49283090e-01, 1.50716910e-01],
#        [9.99033472e-01, 9.66527873e-04],
#        [2.42112955e-02, 9.75788705e-01],
#        [8.06499225e-01, 1.93500775e-01]])
